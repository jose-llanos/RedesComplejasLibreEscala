# %%
import os,glob,pandas as pd,numpy as np,matplotlib.pyplot as plt

# %%
listfolder=['Graficas']
for i in listfolder:
    listtxt=glob.glob(i+'/ResultadosTXT/*.txt')
    df=pd.DataFrame()
    plt.figure(dpi=100)
    for j in listtxt:
        archivo=open(j,"r")
        lineas=archivo.readlines()
        line=lineas[0].split(',')
        df[os.path.basename(j)[:-4]] = line
        df[os.path.basename(j)[:-4]] = pd.to_numeric(df[os.path.basename(j)[:-4]], errors='coerce')
        plt.loglog(range(1,len(df)+1),df[os.path.basename(j)[:-4]],label=os.path.basename(j)[:-4])
    plt.xlabel('Iteración')
    plt.ylabel('Distancia')
    plt.title(i)
    plt.legend()
    plt.grid(ls=':')
    plt.savefig(i+".jpg",dpi=300)
    plt.show()

# %% [markdown]
# ## Comparacion de resultados con 100 iteraciones y 50 generaciones

# %%
listfolder=['Graficas_100']
for i in listfolder:
    listtxt=glob.glob(i+'/ResultadosTXT_100/*.txt')
    df=pd.DataFrame()
    plt.figure(dpi=100)
    for j in listtxt:
        archivo=open(j,"r")
        lineas=archivo.readlines()
        line=lineas[0].split(',')
        df[os.path.basename(j)[:-4]] = line
        df[os.path.basename(j)[:-4]] = pd.to_numeric(df[os.path.basename(j)[:-4]], errors='coerce')
        plt.loglog(range(1,len(df)+1),df[os.path.basename(j)[:-4]],label=os.path.basename(j)[:-4])
    plt.xlabel('Iteración')
    plt.ylabel('Distancia')
    plt.title(i)
    #plt.legend()
    plt.grid(ls=':')
    plt.savefig(i+".jpg",dpi=300)
    plt.show()

# %%
df.head(50)
# Out:
#     barabasibest  barabasi_tsp     evnormal       swbest       sw_tsp
# 0    1733.237304   2115.953208  1807.250044  2093.239000  2008.162895
# 1    1627.072640   2062.087377  1769.975867  2011.483185  1969.786733
# 2    1553.357972   2004.120182  1706.803668  1948.283297  1925.834183
# 3    1493.155952   1972.303804  1667.222082  1904.212747  1901.251418
# 4    1453.527512   1931.001832  1619.884192  1867.474284  1855.752508
# 5    1412.585075   1884.484942  1582.967690  1823.948153  1831.523851
# 6    1377.968943   1839.989860  1553.656666  1794.398618  1815.897339
# 7    1346.155106   1805.111142  1517.115167  1758.929640  1782.418650
# 8    1317.278862   1756.082169  1487.859132  1714.423288  1759.847189
# 9    1287.134908   1723.800493  1464.282630  1689.875448  1722.245850
# 10   1262.964575   1704.542161  1432.123084  1662.523574  1703.066923
# 11   1242.490253   1676.381938  1412.867190  1636.899808  1684.469810
# 12   1221.695090   1651.598522  1388.346894  1611.796867  1657.666774
# 13   1200.088149   1637.956948  1377.855983  1579.928949  1635.760431
