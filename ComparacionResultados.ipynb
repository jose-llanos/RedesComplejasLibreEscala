# %%
import os,glob,pandas as pd,numpy as np,matplotlib.pyplot as plt

# %%
listfolder=['Funcion_Beale','Funcion_Ackley','Funcion_Camel','Funcion_Esfera']
for i in listfolder:
    listtxt=glob.glob(i+'/ResultadosTXT/*.txt')
    df=pd.DataFrame()
    plt.figure(dpi=300)
    for j in listtxt:
        archivo=open(j,"r")
        lineas=archivo.readlines()
        line=lineas[0].split(',')
        df[os.path.basename(j)[:-4]] = line
        df[os.path.basename(j)[:-4]] = pd.to_numeric(df[os.path.basename(j)[:-4]], errors='coerce')
        plt.plot(range(1,len(df)+1),df[os.path.basename(j)[:-4]],label=os.path.basename(j)[:-4])
    plt.xlabel('Iteración')
    plt.ylabel('Fitness')
    plt.title(i)
    plt.legend()
    plt.grid(ls=':')
    plt.savefig(i+".jpg",dpi=300)
    plt.show()

# %%
listfolder=['Funcion_Beale','Funcion_Ackley']
for i in listfolder:
    listtxt=glob.glob(i+'/ResultadosTXT/*.txt')
    df=pd.DataFrame()
    for j in listtxt:
        archivo=open(j,"r")
        lineas=archivo.readlines()
        line=lineas[0].split(',')
        df[os.path.basename(j)[:-4]] = line
        df[os.path.basename(j)[:-4]] = pd.to_numeric(df[os.path.basename(j)[:-4]], errors='coerce')
    df.plot()

# %%
df.head(50)
# Out:
#     Beale_barabasi  Beale_barabasibest  Beale_evolutivo  Beale_sw  \
# 0         0.421432            0.312638         0.711856  0.367009
# 1         0.280478            0.210590         0.477584  0.320913
# 2         0.217531            0.139597         0.355128  0.230669
# 3         0.170632            0.114469         0.262882  0.197482
# 4         0.126289            0.095813         0.233789  0.164292
# 5         0.105536            0.089283         0.194131  0.133226
# 6         0.091423            0.081299         0.173804  0.095643
# 7         0.082967            0.074377         0.169340  0.083489
# 8         0.064869            0.069141         0.148533  0.078128
# 9         0.058450            0.066566         0.143365  0.068606
# 10        0.052154            0.063089         0.135958  0.064661
# 11        0.050632            0.062520         0.135829  0.060401
# 12        0.048235            0.059842         0.119595  0.049732
# 13        0.046255            0.057720         0.116169  0.048459
# 14        0.045175            0.052438         0.106559  0.045223
# 15        0.040701            0.051495         0.103920  0.044440
# 16        0.039633            0.049864         0.102292  0.044914
# 17        0.038771            0.049577         0.094912  0.042399
# 18        0.035764            0.043159         0.092490  0.037496
# 19        0.031915            0.042832         0.090330  0.035167
# 20        0.029745            0.042239         0.088111  0.031609
# 21        0.027564            0.041243         0.086610  0.030647
# 22        0.027307            0.040337         0.077354  0.029849
# 23        0.026678            0.040314         0.076751  0.029020
# 24        0.025681            0.039877         0.076215  0.026974
# 25        0.024058            0.038264         0.075616  0.026500
# 26        0.023623            0.037744         0.073586  0.026307
# 27        0.023295            0.037736         0.072556  0.026467
# 28        0.022542            0.037656         0.071687  0.025929
# 29        0.021956            0.036994         0.071026  0.025399
# 30        0.021909            0.036959         0.068942  0.023749
# 31        0.021093            0.036899         0.065704  0.022757
# 32        0.020872            0.035454         0.064930  0.022757
# 33        0.020264            0.034865         0.063651  0.022313
# 34        0.019997            0.034696         0.061754  0.021775
# 35        0.019772            0.034529         0.061202  0.021894
# 36        0.019404            0.033990         0.060926  0.021046
# 37        0.019052            0.033369         0.059641  0.020256
# 38        0.018822            0.032833         0.059119  0.020405
# 39        0.018494            0.032754         0.058548  0.019934
# 40        0.017821            0.032608         0.057812  0.019423
# 41        0.017651            0.032534         0.057247  0.019100
# 42        0.017050            0.032364         0.056621  0.017926
# 43        0.017369            0.032226         0.055017  0.018909
# 44        0.016845            0.031645         0.054603  0.018750
# 45        0.016613            0.030852         0.053946  0.017741
# 46        0.016243            0.030630         0.053868  0.017367
# 47        0.016288            0.030199         0.053293  0.017123
# 48        0.015813            0.030160         0.051724  0.017337
# 49        0.015230            0.029922         0.050500  0.016560
#
#     Beale_swbest
# 0       0.428925
# 1       0.290067
# 2       0.189319
# 3       0.150087
# 4       0.139439
# 5       0.105559
# 6       0.096737
# 7       0.084766
# 8       0.074778
# 9       0.071230
# 10      0.063888
# 11      0.053540
# 12      0.049998
# 13      0.048625
# 14      0.041374
# 15      0.039342
# 16      0.036584
# 17      0.034585
# 18      0.033773
# 19      0.031614
# 20      0.031393
# 21      0.030443
# 22      0.031156
# 23      0.029966
# 24      0.031750
# 25      0.026795
# 26      0.026513
# 27      0.026239
# 28      0.025431
# 29      0.024044
# 30      0.023798
# 31      0.023817
# 32      0.021915
# 33      0.021921
# 34      0.021743
# 35      0.021743
# 36      0.021591
# 37      0.021372
# 38      0.020835
# 39      0.020744
# 40      0.020421
# 41      0.020606
# 42      0.020408
# 43      0.020227
# 44      0.019900
# 45      0.019900
# 46      0.019867
# 47      0.019849
# 48      0.019812
# 49      0.019526

# %%
np.min(df,axis=0)
# Out:
# Beale_barabasi        0.015230
# Beale_barabasibest    0.029922
# Beale_evolutivo       0.050500
# Beale_sw              0.016560
# Beale_swbest          0.019526
# dtype: float64
